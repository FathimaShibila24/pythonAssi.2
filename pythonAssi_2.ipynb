# %%
import pandas as pd

# %%
#reading an excel file to colab notebook
data = pd.read_excel('/content/iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#display the name of colums in dataset
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#calculate the mean of each columns
data['SL'].mean()
# Out:
# 5.843333333333334

# %%
data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
data['PL'].mean()
# Out:
# 3.758666666666666

# %%
data['PW'].mean()
# Out:
# 1.1986666666666668

# %%
#check for null values in each columns
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#visualise data
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df['species'] = iris.target
species_map = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
df['species'] = df['species'].map(species_map)

plt.figure(figsize=(8, 6))
sns.scatterplot(x='sepal length (cm)', y='petal length (cm)', hue='species', data=df, palette='Set1', s=100)

plt.title('Sepal Length vs Petal Length in Iris Dataset', fontsize=16)
plt.xlabel('Sepal Length (cm)', fontsize=12)
plt.ylabel('Petal Length (cm)', fontsize=12)

plt.show()

# %%
df['species'] = iris.target
species_map = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
df['species'] = df['species'].map(species_map)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(data=df, x='petal length (cm)', hue='species', kde=True, bins=20, palette='Set1', multiple="stack")
plt.title('Petal Length Distribution by Species')

plt.subplot(1, 2, 2)
sns.histplot(data=df, x='petal width (cm)', hue='species', kde=True, bins=20, palette='Set1', multiple="stack")
plt.title('Petal Width Distribution by Species')

plt.tight_layout()
plt.show()
